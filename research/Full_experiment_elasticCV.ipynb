# %% [markdown]
# <a href="https://colab.research.google.com/github/Ray-XXX-eee/ML_002/blob/main/Full_experiment_elasticCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
wine = pd.read_csv('data/WineQT.csv')

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
wine.shape
# Out:
# (1143, 13)

# %%
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
X = wine.drop(['quality'], axis=1)
Y = wine['quality']

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
x_train,x_test, y_train, y_test = train_test_split(X,Y,test_size=.2,random_state=42,shuffle=True)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (914, 12)
# (914,)
# (229, 12)
# (229,)

# %%
from sklearn.linear_model import ElasticNet

# %%
model = ElasticNet(alpha=0.1,l1_ratio=.5,random_state=42)
model.fit(X=x_train,y=y_train)
# Out:
# ElasticNet(alpha=0.1, random_state=42)

# %%
predictions = model.predict(X=x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def eval(actual,predicted):
  print(mean_squared_error(actual,predicted))
  print(mean_absolute_error(actual,predicted))
  print(r2_score(actual,predicted))

# %%
eval(y_test,predictions)
# Out:
# 0.39689490877304945
# 0.5034416470825984
# 0.2867669826959264

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def cal(x:int,y:int)-> int :
    return x*y

cal(2,3)
# Out:
# 6
